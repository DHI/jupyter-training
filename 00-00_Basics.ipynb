# %% [markdown]
# # Segment 0: Data Science Tools
#
# ## Ipython, Jupyter, Spyder

# %% [markdown]
# ### IPython
#
# + “Interactive” Python
# + Program can be written and executed line-by-line
# + User can interact after each command
#
# + Advantage: No need to re-run the complete script to apply changes

# %% [markdown]
# ### Spyder
#
# + IDE-like frontend for Ipython
# + Useful for more complex code projects
# + Matlab-Style (inbuilt visualization of variables, matrices, etc).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Jupyter
#
# + Popular Front-End for Ipython
# + Integrated Reporting Feature (Markdown)
# + Web-Interface (local or remote)
# + Support for non-Python scripts (e.g. R)
#
# ** What you see here is a Jupyter Notebook **

# %% [markdown]
# #### Create a new Workbook
#
# ![image.png](attachment:image.png)

# %%
## This is a simple Code Cell. 
# Enter code and run this cell by CTRL+ENTER
# its output is shown in-line 

print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# You can show graphical output from matplotlib with a magic command:

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline  
# <- magic command: show all plots in notebook

x = np.arange(0, 10, 1)
y = np.arange(0, 20, 2)

plt.scatter(x, y)

# %% [markdown]
# **This is a Markdown Cell**
#
# Markdown Cells are used to document what you have done.
#
# Markdown is a markup language with a very easy syntax for creating rich text.
#
# This is a good reference:
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
#
#
# Inside Jupyter, you can also use LaTex to create formulas:
#
# $q = -k_f \nabla h$
#
# With some extensions, you can also use variables of code cells here.
